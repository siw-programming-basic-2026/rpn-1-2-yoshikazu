# %%
1+1
# Out:
# 2

# %%
import os

# %%
with open("./expressions.txt", "r", encoding="UTF-8") as f:
    for line in f:
        print(line, end="")
        print(line.split())
# Out:
# 3 4 +
# ['3', '4', '+']
# 10 20 +
# ['10', '20', '+']
# 3 +
# ['3', '+']
# 5 a +
# ['5', 'a', '+']
# 3 4 5 +
# ['3', '4', '5', '+']
# 10 2 /
# ['10', '2', '/']
# 10 0 /['10', '0', '/']
